# %% [markdown]
# # Exploring the weight data from Healthkit

# %%
import altair as alt 
import pandas as pd
# Out:
# /workspaces/exploring-healthkit-data/.venv/lib/python3.8/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
weight_data = pd.read_csv("weight.csv")

# %%
weight_data.head()
# Out:
#                    startDate    value unit   sourceName
# 0  2022-01-19 06:22:42 -0800  214.243   lb  Health Mate
# 1  2022-01-18 06:19:00 -0800  215.105   lb  Health Mate
# 2  2022-01-17 08:03:51 -0800  215.969   lb  Health Mate
# 3  2022-01-16 08:21:23 -0800  216.267   lb  Health Mate
# 4  2022-01-15 08:23:47 -0800  214.724   lb  Health Mate

# %%
alt.Chart(weight_data).mark_line().encode(
    x = alt.X("date(startDate)",),
    y = alt.Y("value:Q",),
)
# Out:
# alt.Chart(...)
